# %%
# !uv pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="H22AbAFDpzfnPvomNihN")
project = rf.workspace("potholes-r7qcn").project("pothole-jujbl")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# Audited 1 package in 25ms
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Pothole-1 to yolov11:: 100%|██████████| 146231/146231 [00:45<00:00, 3193.96it/s]
# Extracting Dataset Version Zip to Pothole-1 in yolov11:: 100%|██████████| 5554/5554 [00:00<00:00, 9184.75it/s]
